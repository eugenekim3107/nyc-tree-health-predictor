# %% [markdown]
# # Raw Data
# ---

# %%
import pandas as pd

# %%
#import csv file
tree = pd.read_csv(r'/Users/eugenekim/Downloads/new_york_tree_census_2015.csv')

# %%
#raw data
tree
# Out:
#         tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc status  \
# 0        606945    305778  2016-06-28        10           0   OnCurb  Alive
# 1        160321    341273  2015-08-19         9           0   OnCurb  Alive
# 2        541347    325281  2015-12-30         7           0   OnCurb  Alive
# 3        613930    203822  2016-07-05        10           0   OnCurb  Alive
# 4         18353    338911  2015-06-13         4           0   OnCurb  Alive
# ...         ...       ...         ...       ...         ...      ...    ...
# 683783   237788    223344  2015-09-19         2           0   OnCurb  Alive
# 683784   249489    335314  2015-09-23         2           0   OnCurb   Dead
# 683785   230261    230303  2015-09-16         2           0   OnCurb   Dead
# 683786   623784    318368  2016-07-12        18           0   OnCurb  Alive
# 683787   139749    217836  2015-08-12        11           0   OnCurb  Alive
#
# ...
